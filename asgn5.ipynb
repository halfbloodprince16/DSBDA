# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('fb11.csv',sep=';')
df2 = pd.read_csv('fb22.csv',sep=';')

# %%
df1.head(5)#data intuition
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0     0                       2752                             5091
# 1     0                      10460                            19057
# 2     0                       2413                             4373
# 3     1                      50128                            87991
# 4     0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df1.columns.isna()#no column is having a missing values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
df1.dtypes #data frame object data types
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                     int64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
#1. Data Subsets a.) column wise, b.) row wise

# %%
col_slice = df1.iloc[0:5,4:9]

# %%
col_slice.head()
# Out:
#    Post Weekday  Post Hour  Paid  Lifetime Post Total Reach  \
# 0             4          3     0                       2752
# 1             3         10     0                      10460
# 2             3          3     0                       2413
# 3             2         10     1                      50128
# 4             2          3     0                       7244
#
#    Lifetime Post Total Impressions
# 0                             5091
# 1                            19057
# 2                             4373
# 3                            87991
# 4                            13594

# %%
df1['Page total likes'].unique() , df1['Page total likes'].nunique()
# Out:
# (array([139441, 138414, 138458, 138895, 138353, 138329, 138185, 137893,
#         137177, 137059, 137020, 136736, 136642, 136393, 136013, 135713,
#         135700, 135617, 135428, 135195, 134879, 133679, 133594, 133451,
#         132817, 132201, 131956, 131808, 131728, 131630, 131300, 130791,
#         129600]), 33)

# %%
df2['Page total likes'].unique() , df2['Page total likes'].nunique()
# Out:
# (array([129600, 128032, 127082, 126424, 126345, 126141, 125612, 124940,
#         123047, 121540, 120050, 119198, 117764, 116435, 116091, 115893,
#         115368, 113028, 111620, 109670, 107907, 106928, 104070, 102112,
#         100732,  98195,  96749,  93684,  93577,  93470,  93363,  93256,
#          93149,  93042,  92935,  92828,  92721,  92614,  92507,  92400,
#          92293,  92186,  92079,  91972,  91865,  91758,  91651,  91544,
#          91437,  91330,  91223,  91116,  91009,  86909,  86491,  85979,
#          85093,  81370]), 58)

# %%
#2.) Merging dataframes df1 and df2

# %%
merged_data = pd.merge(df1,df2,on='Page total likes',how='inner')

# %%
merged_data.head() #only five rows matched which has "Page total likes" as common
# Out:
#    Page total likes Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0            129600  Photo           2             7               1
# 1            129600  Photo           2             7               1
# 2            129600  Photo           2             7               1
# 3            129600  Photo           2             7               1
# 4            129600  Photo           2             7               1
#
#    Post Hour_x  Paid_x  Lifetime Post Total Reach_x  \
# 0           12       0                         3460
# 1           12       0                         3460
# 2           12       0                         3460
# 3           12       0                         3460
# 4           12       0                         3460
#
#    Lifetime Post Total Impressions_x  Lifetime Engaged Users_x  ...  \
# 0                               6503                       541  ...
# 1                               6503                       541  ...
# ...

# %%
#3.)Sorting dataframe by a particular column value

# %%
df1.sort_values(by=['Total Interactions'])
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414   Photo         1          12             7         10
# 111            136736   Photo         1          10             6          8
# 100            137020   Photo         1          10             4          9
# 76             137893   Photo         1          11             3          2
# 120            136393   Photo         1          10             7          9
# 129            136393   Photo         1          10             6         12
# 122            136393   Photo         1          10             7          8
# 128            136393   Photo         1          10             6         13
# 123            136393   Photo         1          10             7          7
# 115            136642   Photo         1          10             7         12
# 124            136393   Photo         1          10             7          6
# ...

# %%
#4.) Transposing the dataframe

# %%
transposed_df = df1.T
transposed_df.head(10)
# Out:
#                                     0       1       2       3       4    \
# Page total likes                 139441  139441  139441  139441  139441
# Type                              Photo  Status   Photo   Photo   Photo
# Category                              2       2       3       2       2
# Post Month                           12      12      12      12      12
# Post Weekday                          4       3       3       2       2
# Post Hour                             3      10       3      10       3
# Paid                                  0       0       0       1       0
# Lifetime Post Total Reach          2752   10460    2413   50128    7244
# Lifetime Post Total Impressions    5091   19057    4373   87991   13594
# Lifetime Engaged Users              178    1457     177    2211     671
#
#                                     5       6       7       8       9    ...  \
# Page total likes                 139441  139441  139441  139441  139441  ...
# ...

# %%
#5.) Melting the dataframe

# %%
melted_df = pd.melt(df1,id_vars=['Page total likes'],var_name='Category', value_name='value')
melted_df.head(10)
# Out:
#    Page total likes Category   value
# 0            139441     Type   Photo
# 1            139441     Type  Status
# 2            139441     Type   Photo
# 3            139441     Type   Photo
# 4            139441     Type   Photo
# 5            139441     Type  Status
# 6            139441     Type   Photo
# 7            139441     Type   Photo
# 8            139441     Type  Status
# 9            139441     Type   Photo

# %%
#6.) Long to wide format

# %%
df1.pivot(columns='Paid')
# Out:
#      Page total likes              Type         Category      Post Month  \
# Paid                0         1       0       1        0    1          0
# 0            139441.0       NaN   Photo     NaN      2.0  NaN       12.0
# 1            139441.0       NaN  Status     NaN      2.0  NaN       12.0
# 2            139441.0       NaN   Photo     NaN      3.0  NaN       12.0
# 3                 NaN  139441.0     NaN   Photo      NaN  2.0        NaN
# 4            139441.0       NaN   Photo     NaN      2.0  NaN       12.0
# 5            139441.0       NaN  Status     NaN      2.0  NaN       12.0
# 6                 NaN  139441.0     NaN   Photo      NaN  3.0        NaN
# 7                 NaN  139441.0     NaN   Photo      NaN  3.0        NaN
# 8            139441.0       NaN  Status     NaN      2.0  NaN       12.0
# 9            139441.0       NaN   Photo     NaN      3.0  NaN       12.0
# 10           139441.0       NaN  Status     NaN      2.0  NaN       12.0
# ...
